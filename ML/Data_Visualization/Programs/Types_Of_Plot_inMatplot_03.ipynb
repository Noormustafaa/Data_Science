# %%
#Matplotlib

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# Let's Starts Basics Of matplotlib

# %%
#let's Create an array 

x=np.linspace(0,5,11)
x

y= x **3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %% [markdown]
# plt.plot(x,y) # Note Plot Create line graph

# %%
plt.plot(x,y)
plt
# Out:
# <module 'matplotlib.pyplot' from "C:\\Users\\A.J Compute's\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py">

# %%
#Let's Do Some changing in line changing means adding  labels

plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.xlabel("x-axis")  # Note We Can assign any label
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
# So 
plt.plot(x,y)
plt.title("Dummy Graph") 
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
#plt.Subplot(2,2)
plt.subplot(2,2,1)

plt.plot(x,y)

plt.subplot(2,2,4)

plt.plot(x,y)

plt.subplot(2,2,3)

plt.plot(y,x)

plt.subplot(2,2,2)

plt.plot(x==2,x==2)

# %%
# Object Oriented way

#Note Previously we visualized the Graphs over canvas.
# That backgound is known as canvas  and that background we cant select !  and can't
#change in prevous lecture 

# so For ability to make change that backgound is known as object oriented way 

fig = plt.figure()
axis1=fig.add_axes([0.1,0.1,1,1]) # main axes
axis1.plot(x,y)
axis2=fig.add_axes([0.3,0.4,0.8,0.9]) # main axes
axis2.plot(x,y)  

# Means we can add multiple axes in one figure and we can change the size of axes and position of axes in figure

# %%
# Now Types Of Plots 
plt.scatter(x,y)

# %%
from random import sample 
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 9., 11.,  7.,  8., 13., 13.,  6., 14., 12.,  7.]),
#  array([  8. , 106.3, 204.6, 302.9, 401.2, 499.5, 597.8, 696.1, 794.4,
#         892.7, 991. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(data)
#Note Box plot is used to visualize the distribution of data and to identify outliers in the data. It shows the median, quartiles, and any potential outliers in the dataset.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2386fbbed10>,
#   <matplotlib.lines.Line2D at 0x2386fbbf010>],
#  'caps': [<matplotlib.lines.Line2D at 0x2386fbbf1f0>,
#   <matplotlib.lines.Line2D at 0x2386fbbf4f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2386fbbea10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2386fbbf7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2386fbbfaf0>],
#  'means': []}
