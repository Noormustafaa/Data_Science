# %%
#Matplotlib

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# Let's Starts Basics Of matplotlib

# %%
#let's Create an array 

x=np.linspace(0,5,11)
x

y= x **3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %% [markdown]
# plt.plot(x,y) # Note Plot Create line graph

# %%
plt.plot(x,y)
plt
# Out:
# <module 'matplotlib.pyplot' from "C:\\Users\\A.J Compute's\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py">

# %%
#Let's Do Some changing in line changing means adding  labels

plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.xlabel("x-axis")  # Note We Can assign any label
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
# So 
plt.plot(x,y)
plt.title("Dummy Graph") 
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
#plt.Subplot(2,2)
plt.subplot(2,2,1)

plt.plot(x,y)

plt.subplot(2,2,4)

plt.plot(x,y)

plt.subplot(2,2,3)

plt.plot(y,x)

plt.subplot(2,2,2)

plt.plot(x==2,x==2)

# %%
# Object Oriented way

#Note Previously we visualized the Graphs over canvas.
# That backgound is known as canvas  and that background we cant select !  and can't
#change in prevous lecture 

# so For ability to make change that backgound is known as object oriented way 

fig = plt.figure()
axis1=fig.add_axes([0.1,0.1,1,1]) # main axes
axis1.plot(x,y)
axis2=fig.add_axes([0.3,0.4,0.8,0.9]) # main axes
axis2.plot(x,y)  

# Means we can add multiple axes in one figure and we can change the size of axes and position of axes in figure

# %%
# Now Types Of Plots 
plt.scatter(x,y)

# %%
from random import sample 
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 8., 14., 13.,  9., 11., 10., 10., 12.,  8.,  5.]),
#  array([  7. , 105.3, 203.6, 301.9, 400.2, 498.5, 596.8, 695.1, 793.4,
#         891.7, 990. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(data)
#Note Box plot is used to visualize the distribution of data and to identify outliers in the data. It shows the median, quartiles, and any potential outliers in the dataset.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bf4cda7af0>,
#   <matplotlib.lines.Line2D at 0x1bf4cda7df0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1bf4cfe0130>,
#   <matplotlib.lines.Line2D at 0x1bf4cfe0430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1bf4cda77f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bf4cfe0730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bf4cfe0a30>],
#  'means': []}

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,1,1])
ax.plot(x,y)
plt.savefig("Basic Plot.png")

# %%
#Working with images in matplotlib
#Note Matplotlib can also be used to display images. You can use the `imshow()` function to display an image in a plot.
#matplotlip easily work with images because it work with numpy array and images are also represented as numpy array
# 
# Step 1load an image 
# For that we have to import an other library which is !
import matplotlib.image as mpimg

img = mpimg.imread("Salman.png")
img
# it will show in array form 
# so Write 
plt.imshow(img) # so till  here we can see image but in image it is showing the Axis So let's hide it 

plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(486.5), np.float64(416.5), np.float64(-0.5))

# %%
# Note we can crop this picture as well 
cropped_img =img[50:200,100:300]
plt.imshow(cropped_img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %%
plt.plot(x,y,color="yellow")

# %%
xaxis = np.linspace(0, 5, 11)

fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(xaxis, xaxis + 1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis + 2, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis + 3, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis + 4, color="red", linewidth=2.00)

# possible linestyles options '-', '--', '-.', ':', 'steps'
ax.plot(xaxis, xaxis + 5, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis + 6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis + 7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis + 8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10])  # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis + 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis + 10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis + 11, color="blue", lw=3, ls='--', marker='s')
ax.plot(xaxis, xaxis + 12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis + 13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis + 14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis + 15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(
    xaxis,
    xaxis + 16,
    color="purple",
    lw=1,
    ls='-',
    marker='s',
    markersize=8,
    markerfacecolor="yellow",
    markeredgewidth=3,
    markeredgecolor="green",
);
