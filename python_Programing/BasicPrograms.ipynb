# %%
# print

print("Hello_World")  # print() is the function in python

print("NoorMustafa ", " \n Rajpar ")
# Out:
# Hello_World
# NoorMustafa
#  Rajpar

# %%
##print Numbers
print(5)

print(2+3) #=5
# Out:
# 5
# 5

# %%
# Variables : Is a name given to a memory location in a program 
#ex
name = "Noor"
#var    Value

age =     10
# Literals : are Fixed Values  Written Directly in the code 
# ex 10 is here Integral Literal 


#in Python for looking variable memory adress  we use id() Function


print(id(age)) # this is how we can see 
#Ye number memory address ka unique identifier hota hai
# (exact address nahi, balkay address ka reference hota hai)


#type of variable 

print("Variable Type is ",type(age))

print("Variable Type is ",type(name))
# Out:
# 1632710820368
# Variable Type is  <class 'int'>
# Variable Type is  <class 'str'>

# %%
# Data Types in Python 
#Integer (whole Values like 0,2,-2), Float , String (can be write (single Quote, double or Triple ) ), Boolean , None
name1   =True
print(type(name1))
# Out:
# <class 'bool'>

# %%
#keywords in python are the reserved word which are exist 
#in python 

#Comments in Python ! are those which compiler does not execute 

# single Line Comment we use # operator
# for multi line we use """ triple Quotes
#ex 
"""
Rough


"""


# or control and forward slash


# This is rough

# %%
# Operators 
#An operator is a symbol That Performs a certain Operation  Between 
#operands 

#Types of op
#Arthematic op , +,-, *, **(Power op) 
#Relatonal Or Comparision Operator , to compare 2 values (==,!= ,>,<)
#
print (2==5)#false  

#Assignment op , =,+=,/=,%=

#Logical operaotrs (it works on boolean operators ) 
# there are three logi op not , and ,or
#ex
print (not True) 
a=3
b=2
print (not (a>b))
# Out:
# False
# False
# False

# %%
# Type Conversion (means Convert variable one type to another type )
#there are two types of conversion 
# type conversion(automatic Conversion) Python intrepror do itseld 
#type casting  we do menually , means forcely 

#type conve

a=2
b=3.24
sum=a+b #5.24
print(sum)

# Float is here superior data type that's why it will convert automatic

#but a="2"
#b=3
#sum=(a+b) not possible we have to do it manualy 


#Type Casting

a,b=3,"2"
c=int(b)
sum =a+c
print(sum)

a=3.14
b=str(a)
print(type(b))
# Out:
# 5.24
# 5
# <class 'str'>

# %%
# Taking input from user

a=input("Enter Any Number")

print(type(a))

b=int(input("Enter your second number"))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
