# %%
#functions Block of statements That perform a specific task 
def sum(a,b):
    sum=a+b
    print(sum)
    return sum


sum(2,3)


sum(4,2)
# Out:
# 5
# 6
# 6

# %%
def cal_sum(a,b):
    return a+b



cal_sum(2,6) # jupitor atomatic return its value
# Out:
# 8

# %%
#in Python There are two types of Functions
#1 Bultin Functions like print() len() type() range()
#User Define Fun

print("noor", end=" ") # for same line 
print ("mustafa")

# %%
def cal(a,b=2):
    print(a*b)
    return a*b


cal(1)
# Out:
# 2
# 2
