# %%
# !pip install -q openai # method 1 using SDK practical 

# Diagram 

#Your Python Code
 #      ↓
#OpenAI Python SDK
#       ↓
#HTTP Request
#      ↓
#OpenAI API
#       ↓
#Response
#       ↓
#SDK
#       ↓
#Python Object
# Out:
# WARNING: Ignoring invalid distribution -lotly (c:\users\a.j compute's\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\a.j compute's\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\a.j compute's\appdata\roaming\python\python310\site-packages)

# %%
from openai import OpenAI

client = OpenAI(api_key="YourApiKey")

response = client.responses.create(
    model="gpt-5.6",
    input="Hello"
)
