# %%
class Student:
    def __init__(self, phy, chem, math):
        self.phy = phy
        self.chem = chem
        self.math = math
    #    self.percentage = str((self.phy + self.chem + self.math) / 3) + "%"

    #def update_percentage(self):
     #   self.percentage = str((self.phy + self.chem + self.math) / 3) + "%"

        # so here when an attribute value is depent over the function for chaninging it's value so what we do we make that function as it's property 
    @property
    def percentage(self):
        return str((self.phy + self.chem + self.math) / 3) + "%"

stu1 = Student(98, 97, 99)
print(stu1.percentage)

stu1.phy = 86
#print(stu1.phy)  # note here marks are changed but percentage is not changed because percentage is calculated in constructor and it is not updated when marks are changed. So we need to update percentage when marks are changed.
print(stu1.percentage) 

# in thi way automated changes are happend
# Out:
# 98.0%
# 94.0%
